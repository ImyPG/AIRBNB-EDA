# %% [markdown]
# Comparison of my 3 cities: London, Amsterdam and Mexico City

# %% [markdown]
# # Prerequisite
#
# Download pandas library by running the following code.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\imypo\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\imypo\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\imypo\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\imypo\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\imypo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %% [markdown]
# # Exploratory data analysis (EDA)

# %% [markdown]
# You will learn how to systematically approach investigating an unknown dataset while maintaining a creative and open mind to search for insights.

# %% [markdown]
# ## Context
# Airbnb is an online marketplace for people to rent places to stay.
#
# Airbnb has rolled out a new service to help listers set prices. Airbnb makes a percentage commission off of the listings, so they are incentivized to help listers price optimally; that is, at the maximum possible point where they will still close a deal. You are an Airbnb consultant helping with this new pricing service.

# %% [markdown]
# ## Goal
#
# We are going to focus on a question: which features are helpful for finding out the appropriate listing price?

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

# %%
listings_ams = pd.read_csv('data/listings_amsterdam.csv', delimiter=",", encoding='utf-8')

# %%
listings_lon = pd.read_csv('data/listings_london.csv',error_bad_lines=False)
# Out:
# b'Skipping line 3134: expected 18 fields, saw 3599\nSkipping line 5659: expected 18 fields, saw 5812\nSkipping line 8253: expected 18 fields, saw 57\nSkipping line 9943: expected 18 fields, saw 800\nSkipping line 10610: expected 18 fields, saw 2180\nSkipping line 25189: expected 18 fields, saw 2764\nSkipping line 25774: expected 18 fields, saw 1495\n'
# b'Skipping line 37991: expected 18 fields, saw 2137\nSkipping line 38669: expected 18 fields, saw 1130\nSkipping line 47821: expected 18 fields, saw 935\nSkipping line 50872: expected 18 fields, saw 438\nSkipping line 53511: expected 18 fields, saw 4650\nSkipping line 58417: expected 18 fields, saw 1239\n'
# C:\Users\imypo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
listings_mex = pd.read_csv('data/listings_mexico.csv',error_bad_lines=False)
# Out:
# b'Skipping line 1087: expected 18 fields, saw 857\nSkipping line 2927: expected 18 fields, saw 328\nSkipping line 2953: expected 18 fields, saw 165\nSkipping line 3937: expected 18 fields, saw 93\nSkipping line 4689: expected 18 fields, saw 1297\nSkipping line 5174: expected 18 fields, saw 236\nSkipping line 5906: expected 18 fields, saw 767\nSkipping line 8592: expected 18 fields, saw 181\nSkipping line 10354: expected 18 fields, saw 166\nSkipping line 11218: expected 18 fields, saw 1629\nSkipping line 11225: expected 18 fields, saw 3079\n'

# %%
listings_lon['City']= 'London'

# %%
listings_ams['City']= 'Amsterdam'

# %%
listings_mex['City']= 'Mexico_City'

# %%
All_listings = pd.concat([listings_ams, listings_lon, listings_mex])
All_listings
# Out:
#                                                       id  \
# 0                                                   2818
# 1                                                  20168
# 2      27886,"Romantic, stylish B&B houseboat in cana...
# 3                                                  28871
# 4                                                  29051
# ...                                                  ...
# 16321                                           52995365
# 16322                                           52995536
# 16323                                           52995666
# 16324                                           52995761
# 16325                                           52995861
#
#                                                name      host_id  host_name  \
# 0          Quiet Garden View Room & Super Fast WiFi         3159     Daniel
# 1      Studio with private bathroom in the centre 1        59484  Alexander
# 2                                               NaN          NaN        NaN
# 3                           Comfortable double room       124245      Edwin
# 4                           Comfortable single room       124245      Edwin
# ...                                             ...          ...        ...
# 16321               Mr. W | Kin Pech | Mexican Loft  428977921.0   Kin Pech
# 16322                   Mr. W | Kin Pech | New Chic  428977921.0   Kin Pech
# 16323         Mr. W | Kin Pech | Location +.Comfort  428977921.0   Kin Pech
# 16324              Mr. W | Kin Pech | Ph in La Roma  428977921.0   Kin Pech
# 16325                     Mr. W | Kin Pech | Rufino  428977921.0   Kin Pech
#
#       neighbourhood_group                           neighbourhood   latitude  \
# 0                     NaN  Oostelijk Havengebied - Indische Buurt  52.364350
# 1                     NaN                            Centrum-Oost  52.364070
# 2                     NaN                                     NaN        NaN
# 3                     NaN                            Centrum-West  52.367750
# 4                     NaN                            Centrum-Oost  52.365840
# ...                   ...                                     ...        ...
# 16321                 NaN                              Cuauhtémoc  19.409333
# 16322                 NaN                              Cuauhtémoc  19.409074
# 16323                 NaN                              Cuauhtémoc  19.408692
# 16324                 NaN                              Cuauhtémoc  19.410494
# 16325                 NaN                              Cuauhtémoc  19.410433
#
#        longitude        room_type   price  minimum_nights number_of_reviews  \
# 0        4.94358     Private room    59.0             3.0               282
# 1        4.89393     Private room   106.0             1.0               339
# 2            NaN              NaN     NaN             NaN               NaN
# 3        4.89092     Private room    75.0             2.0               364
# 4        4.89111     Private room    55.0             2.0               509
# ...          ...              ...     ...             ...               ...
# 16321 -99.163484  Entire home/apt  3229.0             1.0               0.0
# 16322 -99.163766  Entire home/apt  5997.0             1.0               0.0
# 16323 -99.164774  Entire home/apt  3229.0             1.0               0.0
# 16324  -99.16513  Entire home/apt  3229.0             1.0               0.0
# 16325 -99.163614  Entire home/apt  5997.0             1.0               0.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-21               2.83                             1.0
# 1      2020-03-27               3.57                             2.0
# 2             NaN                NaN                             NaN
# 3      2021-10-15               4.62                             2.0
# 4      2021-10-09               5.52                             2.0
# ...           ...                ...                             ...
# 16321         NaN                NaN                             9.0
# 16322         NaN                NaN                             9.0
# 16323         NaN                NaN                             9.0
# 16324         NaN                NaN                             9.0
# 16325         NaN                NaN                             9.0
#
#        availability_365 number_of_reviews_ltm                   license;  \
# 0                  33.0                     4  0363 5F3A 5684 6750 D14D;
# 1                   0.0                     0  0363 CBB3 2C10 0C2A 1E29;
# 2                   NaN                   NaN                        NaN
# 3                 267.0                    28  0363 607B EA74 0BD8 2F6F;
# 4                 282.0                    30  0363 607B EA74 0BD8 2F6F;
# ...                 ...                   ...                        ...
# 16321             365.0                   0.0                        NaN
# 16322             365.0                   0.0                        NaN
# 16323             365.0                   0.0                        NaN
# 16324             365.0                   0.0                        NaN
# 16325             365.0                   0.0                        NaN
#
#               City license;;
# 0        Amsterdam       NaN
# 1        Amsterdam       NaN
# 2        Amsterdam       NaN
# 3        Amsterdam       NaN
# 4        Amsterdam       NaN
# ...            ...       ...
# 16321  Mexico_City        ;;
# 16322  Mexico_City        ;;
# 16323  Mexico_City        ;;
# 16324  Mexico_City        ;;
# 16325  Mexico_City        ;;
#
# [80376 rows x 20 columns]

# %% [markdown]
# ## Activities

# %% [markdown]
# **Q:** Can you view/print the data?

# %%
All_listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license;', 'City',
#        'license;;'],
#       dtype='object')

# %%
All_listings['number_of_reviews'].value_counts(normalize=True)
# Out:
# 0        0.210443
# 1        0.093545
# 2        0.056615
# 0.0      0.049355
# 3        0.041915
#            ...
# 461      0.000015
# 296.0    0.000015
# 295.0    0.000015
# 650      0.000015
# 511      0.000015
# Name: number_of_reviews, Length: 788, dtype: float64

# %% [markdown]
# **Q:** How large is this data?

# %%
All_listings.shape
# Out:
# (80376, 20)

# %% [markdown]
# **Q:** Tell me the types of each variables using ```info()``` method?

# %%
All_listings.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                          object
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                  object
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm              object
# license;                           object
# City                               object
# license;;                          object
# dtype: object

# %%
All_listings.loc[:20000,[ 'City','reviews_per_month','number_of_reviews']]
# Out:
#             City  reviews_per_month number_of_reviews
# 0      Amsterdam               2.83               282
# 1      Amsterdam               3.57               339
# 2      Amsterdam                NaN               NaN
# 3      Amsterdam               4.62               364
# 4      Amsterdam               5.52               509
# ...          ...                ...               ...
# 19996     London               0.74                25
# 19997     London               1.81                75
# 19998     London                NaN               NaN
# 19999     London               0.69                33
# 20000     London                NaN               NaN
#
# [25409 rows x 3 columns]

# %%
All_listings['price'].describe()
# Out:
# count     66802.000000
# mean        376.904180
# std        1909.466498
# min           0.000000
# 25%          55.000000
# 50%         110.000000
# 75%         275.000000
# max      350000.000000
# Name: price, dtype: float64

# %%
All_listings['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Q:** Can you filter/output the listings which has more than 10 reviews (```number_of_reviews```>10) AND has lower than 50 ratings (```review_scores_rating```<50)?

# %%
condition_bad = (All_listings['number_of_reviews']>10) & (listings['review_scores_rating']<75)
condition_good = (All_listings['number_of_reviews']>10) & (listings['review_scores_rating']>=75)
listings[condition_good]
# Out:
#                                                        name  \
# id
# 8505                     Sunny Bedroom Across Prospect Park
# 12299                   Beautiful Sunny Park Slope Brooklyn
# 12627     Entire apartment in central Brooklyn neighborh...
# 13050                             bright and stylish duplex
# 14322                   Beautiful Apartment in Manhattan!!!
# ...                                                     ...
# 35136523  PRIVATE, NEWLY RENOVATED BEDROOM, 10 MINS FROM...
# 35167554                Cozy and private room close to LGA.
# 35247268             ☕Perfect 2-bdr close to Times Square ✨
# 35480817            ★★★Chic place in center of Manhattan★★★
# 35495582  ★ AMAZING★  TIME SQUARE/ 2 Bedroom 3 Bed Apart...
#
#                                                     summary  \
# id
# 8505      Just renovated sun drenched bedroom in a quiet...
# 12299                                                   NaN
# 12627     My place is close to Prospect Park  and you’ll...
# 13050     Wonderfully bright, comfortable, and stylish, ...
# 14322     You will find a welcoming apartment, I love to...
# ...                                                     ...
# 35136523  This is a newly renovated bedroom located in L...
# 35167554  Cozy room with 2 big windows, 6 min from/to LG...
# 35247268  All you need 2-bdr apt in the center of Manhat...
# 35480817  All you need 2-bdr apt in the center of Manhat...
# 35495582  ★ AMAZING★ 2 Bedroom 3 bed apartment in NYC/TI...
#
#                                                 description  \
# id
# 8505      Just renovated sun drenched bedroom in a quiet...
# 12299     This is a large one bedroom apartment located ...
# 12627     My place is close to Prospect Park  and you’ll...
# 13050     Wonderfully bright, comfortable, and stylish, ...
# 14322     You will find a welcoming apartment, I love to...
# ...                                                     ...
# 35136523  This is a newly renovated bedroom located in L...
# 35167554  Cozy room with 2 big windows, 6 min from/to LG...
# 35247268  All you need 2-bdr apt in the center of Manhat...
# 35480817  All you need 2-bdr apt in the center of Manhat...
# 35495582  ★ AMAZING★ 2 Bedroom 3 bed apartment in NYC/TI...
#
#          experiences_offered  \
# id
# 8505                    none
# 12299                   none
# 12627                   none
# 13050                   none
# 14322                   none
# ...                      ...
# 35136523                none
# 35167554                none
# 35247268                none
# 35480817                none
# 35495582                none
#
#                                       neighborhood_overview  \
# id
# 8505      Quiet and beautiful Windsor Terrace. The apart...
# 12299                                                   NaN
# 12627     Steps from Beautiful Prospect Park, Zoo, Brook...
# 13050     The Putnam-Throop area of Bed-Stuy is a vibran...
# 14322     They are very private, so please respect their...
# ...                                                     ...
# 35136523  The house is located 10 minutes away from JFK ...
# 35167554                                                NaN
# 35247268  Hell's Kitchen, also known as Clinton, is a ne...
# 35480817                                                NaN
# 35495582  NYC HEART OF THE CITY A C E and 1 all within  ...
#
#                                                     transit  \
# id
# 8505      Ten minutes walk to the 15th sheet F&G train s...
# 12299                                                   NaN
# 12627     NYC Subway lines Q, B, and S to Prospect Park....
# 13050     Three useful buses (26, 52, 43) are three or f...
# 14322     You have trains N/R/6 and buses(on 2av, 3ave 2...
# ...                                                     ...
# 35136523                                                NaN
# 35167554                                                NaN
# 35247268  Several subway / metro stations are within 5-1...
# 35480817  Several subway / metro stations are within 5-1...
# 35495582  3 minutes walking to subway station. perfect l...
#
#                                                 house_rules    host_id  \
# id
# 8505      - No shoes in the house - Quiet hours after 11...      25326
# 12299                                                   NaN      47610
# 12627                                                   NaN      49670
# 13050     Absolutely, positively NO smoking, either insi...      50846
# 14322     Cleaning fee is required. NO SHOES USED IN THE...      56284
# ...                                                     ...        ...
# 35136523  No smoking. Please keep noises down as there a...  107915864
# 35167554                                                NaN  264854526
# 35247268                                                NaN  265271198
# 35480817                                                NaN  266828681
# 35495582  WELCOME!!! HOUSE RULES 1. Check out is at 10 A...  266992480
#
#           host_since  host_response_time  ...  hot_tub_sauna_or_pool  \
# id                                        ...
# 8505         40006.0      within an hour  ...                     -1
# 12299        40108.0  a few days or more  ...                     -1
# 12627        40115.0        within a day  ...                     -1
# 13050        40119.0        within a day  ...                     -1
# 14322        40138.0        within a day  ...                      1
# ...              ...                 ...  ...                    ...
# 35136523     42724.0      within an hour  ...                     -1
# 35167554     43614.0      within an hour  ...                     -1
# 35247268     43615.0      within an hour  ...                     -1
# 35480817     43622.0      within an hour  ...                     -1
# 35495582     43623.0      within an hour  ...                     -1
#
#           internet  long_term_stays  pets_allowed private_entrance secure  \
# id
# 8505             1               -1            -1               -1     -1
# 12299            1               -1            -1               -1     -1
# 12627            1                1            -1               -1     -1
# 13050            1               -1            -1               -1      1
# 14322            1               -1             1               -1     -1
# ...            ...              ...           ...              ...    ...
# 35136523         1               -1            -1               -1     -1
# 35167554         1               -1            -1               -1     -1
# 35247268         1                1            -1               -1     -1
# 35480817         1                1            -1               -1     -1
# 35495582         1                1            -1                1     -1
#
#           self_check_in  smoking_allowed accessible event_suitable
# id
# 8505                 -1               -1         -1             -1
# 12299                -1               -1         -1             -1
# 12627                -1               -1         -1             -1
# 13050                -1               -1         -1             -1
# 14322                -1               -1         -1             -1
# ...                 ...              ...        ...            ...
# 35136523              1               -1         -1             -1
# 35167554             -1               -1         -1             -1
# 35247268             -1               -1         -1             -1
# 35480817             -1               -1          1             -1
# 35495582             -1               -1         -1             -1
#
# [4573 rows x 80 columns]

# %% [markdown]
# **Q:** Can you tabulate ```self_check_in``` function?
#
# Hint: use ```value_counts()``` method.

# %%
listings['self_check_in'].value_counts()
# Out:
# -1    24878
#  1     5301
# Name: self_check_in, dtype: int64

# %%
listings['self_check_in'].value_counts(normalize=True)
# Out:
# -1    0.824348
#  1    0.175652
# Name: self_check_in, dtype: float64

# %% [markdown]
# **Q:** Which features have NaN variables?
#
# Hint: You can use ```any()``` function :)

# %%
listings.isna()
# Out:
#            name  summary  description  experiences_offered  \
# id
# 2539      False    False        False                False
# 3647      False     True        False                False
# 7750      False     True        False                False
# 8505      False    False        False                False
# 8700      False    False        False                False
# ...         ...      ...          ...                  ...
# 36484363  False    False        False                False
# 36484665  False    False        False                False
# 36485057  False     True         True                False
# 36485609  False     True         True                False
# 36487245  False    False        False                False
#
#           neighborhood_overview  transit  house_rules  host_id  host_since  \
# id
# 2539                      False    False        False    False       False
# 3647                       True     True        False    False       False
# 7750                       True     True         True    False       False
# 8505                      False    False        False    False       False
# 8700                       True    False         True    False       False
# ...                         ...      ...          ...      ...         ...
# 36484363                  False    False        False    False       False
# 36484665                  False    False         True    False       False
# 36485057                   True     True         True    False       False
# 36485609                   True     True         True    False       False
# 36487245                   True     True         True    False       False
#
#           host_response_time  ...  hot_tub_sauna_or_pool  internet  \
# id                            ...
# 2539                   False  ...                  False     False
# 3647                   False  ...                  False     False
# 7750                   False  ...                  False     False
# 8505                   False  ...                  False     False
# 8700                    True  ...                  False     False
# ...                      ...  ...                    ...       ...
# 36484363               False  ...                  False     False
# 36484665               False  ...                  False     False
# 36485057               False  ...                  False     False
# 36485609               False  ...                  False     False
# 36487245                True  ...                  False     False
#
#           long_term_stays  pets_allowed  private_entrance  secure  \
# id
# 2539                False         False             False   False
# 3647                False         False             False   False
# 7750                False         False             False   False
# 8505                False         False             False   False
# 8700                False         False             False   False
# ...                   ...           ...               ...     ...
# 36484363            False         False             False   False
# 36484665            False         False             False   False
# 36485057            False         False             False   False
# 36485609            False         False             False   False
# 36487245            False         False             False   False
#
#           self_check_in  smoking_allowed  accessible  event_suitable
# id
# 2539              False            False       False           False
# 3647              False            False       False           False
# 7750              False            False       False           False
# 8505              False            False       False           False
# 8700              False            False       False           False
# ...                 ...              ...         ...             ...
# 36484363          False            False       False           False
# 36484665          False            False       False           False
# 36485057          False            False       False           False
# 36485609          False            False       False           False
# 36487245          False            False       False           False
#
# [30179 rows x 80 columns]

# %%
listings.isna().any(axis=0)
# Out:
# name                      True
# summary                   True
# description               True
# experiences_offered      False
# neighborhood_overview     True
#                          ...
# secure                   False
# self_check_in            False
# smoking_allowed          False
# accessible               False
# event_suitable           False
# Length: 80, dtype: bool

# %% [markdown]
# **Q:** List your insights/takeaways from exploring this data.

# %%
All_listings.groupby(['City','room_type']).agg({'id':['count'],
                                       'price':['mean']})
# Out:
#                                 id        price
#                              count         mean
# City        room_type
# Amsterdam   48                   1     2.000000
#             75                   1    12.000000
#             Entire home/apt   3033   193.746456
#             Hotel room          79   136.481013
#             Private room      1446   113.589212
#             Shared room         16    89.375000
# London      45                   1     2.000000
#             75                   1     1.000000
#             Entire home/apt  27062   180.466780
#             Hotel room         259   152.984556
#             Private room     21121    79.384641
#             Shared room        360    69.850000
# Mexico_City Entire home/apt   7549  1670.143860
#             Hotel room         140  1349.000000
#             Private room      5505   876.408174
#             Shared room        228   733.307018

# %% [markdown]
# Please, feel free to explore more! Bonus points for adding more questinos :)

# %%
x=listings.groupby(['neighbourhood']).agg({'id':['count'],
                                       'review_scores_rating':['mean'],'price':['mean']})
x
# Out:
#                    id review_scores_rating       price
#                 count                 mean        mean
# neighbourhood
# Allerton            3            93.333333   73.333333
# Alphabet City     167            93.902439  160.634731
# Annadale            2            97.500000   91.500000
# Astoria           454            95.083591  100.702643
# Bath Beach          2                  NaN   64.000000
# ...               ...                  ...         ...
# Williamsburg     1238            95.277149  133.893376
# Windsor Terrace    40            96.791667  136.725000
# Woodhaven          37            94.785714   72.567568
# Woodlawn            2           100.000000   74.000000
# Woodside           55            93.800000   80.072727
#
# [186 rows x 3 columns]

# %%
x.hist()
# Out:
# array([[<AxesSubplot:title={'center':"('id', 'count')"}>,
#         <AxesSubplot:title={'center':"('review_scores_rating', 'mean')"}>],
#        [<AxesSubplot:title={'center':"('price', 'mean')"}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## References
#
# "New York", Inside Airbnb, http://insideairbnb.com/get-the-data.html
